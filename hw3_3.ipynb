# %% [markdown]
# <a href="https://colab.research.google.com/github/binodrizal/DSIC401/blob/main/hw3_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
dat={"grp": ["A","A","B","B"],
"sex":["F","M","F","M"],
"meanL":[0.225,0.47,0.325,0.547],
"sdL":[0.106,.325,.106,.308],
"meanR":[.34,.57,.4,.647],
"sdR ":[0.0849, 0.325, 0.0707, 0.274]}
df=pd.DataFrame(dat)
df_wide=pd.pivot(df,index="grp", columns="sex").reset_index().round(3)
df_wide
# Out:
#     grp  meanL           sdL        meanR          sdR
# sex          F      M      F      M     F      M      F      M
# 0     A  0.225  0.470  0.106  0.325  0.34  0.570  0.085  0.325
# 1     B  0.325  0.547  0.106  0.308  0.40  0.647  0.071  0.274
